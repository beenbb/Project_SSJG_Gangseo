# %% [markdown]
# # 상관분석

# %%
# 데이터들 가져오기.

import pandas as pd

file_path = '/Users/raekkkky/Desktop/DNA/[24 1학기] 🏆승승장구/강서_최종 제출/데이터/최종 데이터프레임.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#     행정동  어린이 인구  장애인 인구  노인 인구  어린이 비율  장애인 비율   노인 비율   유동인구  학교(전체)  유아시설  \
# 0   염창동    7791    1065   4872  0.1885  0.0258  0.1179  32482       5    30
# 1  등촌1동    2375     735   3226  0.0954  0.0295  0.1296  31546       1    13
# 2  등촌2동    2372     719   3520  0.1222  0.0370  0.1813  16456       6    13
# 3  등촌3동    3047    3649   7442  0.1031  0.1235  0.2518  55894      12    21
# 4  화곡본동    3596    1390   5379  0.1085  0.0420  0.1624  25690       4    27
#
#    ...  노인장애인보호구역  어린이보호구역   주차장  무인 단속 CCTV  CCTV 총합  불법주정차 단속건수  사망 건수  \
# 0  ...          0        6   429           9      160        7495      9
# 1  ...          1        3   493           3      107        6341      4
# 2  ...          0        3   849           2      128        1888      0
# 3  ...          2        6   235           5      112        2824      2
# 4  ...          2        7  2041           3      357        4098      1
#
#    사고 건수  횡단보도  교통안전지표
# 0    265    14  0.0715
# 1    133    17  0.0615
# 2    129     3  0.0737
# 3    217    45  0.0962
# 4    238     6  0.1043
#
# [5 rows x 26 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 상관관계 계산
corr = df.corr()

# Heatmap 그리기
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('상관관계 플롯')
plt.show()
# Out:
# /var/folders/cx/r_wdv_3d2q7_cr1m0yrq3dph0000gn/T/ipykernel_8802/3085481946.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 47536 (\N{HANGUL SYLLABLE RIN}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50528 (\N{HANGUL SYLLABLE AE}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 53469 (\N{HANGUL SYLLABLE TAEG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50704 (\N{HANGUL SYLLABLE YEL}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 54187 (\N{HANGUL SYLLABLE PES}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49468 (\N{HANGUL SYLLABLE SEN}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 54633 (\N{HANGUL SYLLABLE HAB}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 48520 (\N{HANGUL SYLLABLE BUL}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 48277 (\N{HANGUL SYLLABLE BEOB}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 47581 (\N{HANGUL SYLLABLE MANG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 54945 (\N{HANGUL SYLLABLE HOENG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.draw()
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47215 (\N{HANGUL SYLLABLE ROS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47536 (\N{HANGUL SYLLABLE RIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50528 (\N{HANGUL SYLLABLE AE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53469 (\N{HANGUL SYLLABLE TAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50704 (\N{HANGUL SYLLABLE YEL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54187 (\N{HANGUL SYLLABLE PES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49468 (\N{HANGUL SYLLABLE SEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54633 (\N{HANGUL SYLLABLE HAB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48520 (\N{HANGUL SYLLABLE BUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48277 (\N{HANGUL SYLLABLE BEOB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47581 (\N{HANGUL SYLLABLE MANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54945 (\N{HANGUL SYLLABLE HOENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
threshold = 0.9

# 상관관계가 0.8 이상인 경우 출력
for column in corr.columns:
    related_columns = corr.index[corr[column] >= threshold]
    for related_column in related_columns:
        if related_column != column:
            correlation_value = corr.loc[related_column, column]
            print(f"{related_column} 와 {column} 사이의 상관관계: {correlation_value:.2f}")

# 출력 예시
# A와 B 사이의 상관관계: 0.85
# X와 Y 사이의 상관관계: 0.90
# ...
# Out:
# 어린이 비율 와 어린이 인구 사이의 상관관계: 0.90
# 어린이 인구 와 어린이 비율 사이의 상관관계: 0.90

# %%
threshold = 0.2

# 상관관계가 0.8 이상인 경우 출력
for column in corr.columns:
    related_columns = corr.index[abs(corr[column]) <= threshold]
    for related_column in related_columns:
        if related_column != column:
            correlation_value = corr.loc[related_column, column]
            print(f"{related_column} 와 {column} 사이의 상관관계: {correlation_value:.2f}")

# 출력 예시
# A와 B 사이의 상관관계: 0.85
# X와 Y 사이의 상관관계: 0.90
# ...
# Out:
# 장애인 인구 와 어린이 인구 사이의 상관관계: -0.06
# 주점 와 어린이 인구 사이의 상관관계: -0.01
# 공원 와 어린이 인구 사이의 상관관계: -0.01
# 노인장애인보호구역 와 어린이 인구 사이의 상관관계: 0.02
# 주차장 와 어린이 인구 사이의 상관관계: 0.16
# 사망 건수 와 어린이 인구 사이의 상관관계: 0.19
# 어린이 인구 와 장애인 인구 사이의 상관관계: -0.06
# 주점 와 장애인 인구 사이의 상관관계: 0.19
# 공동주택 와 장애인 인구 사이의 상관관계: -0.07
# 공원 와 장애인 인구 사이의 상관관계: 0.07
# 주차장 와 장애인 인구 사이의 상관관계: -0.07
# 사망 건수 와 장애인 인구 사이의 상관관계: 0.16
# 교통안전지표 와 장애인 인구 사이의 상관관계: 0.10
# 어린이 비율 와 노인 인구 사이의 상관관계: 0.17
# 장애인 비율 와 노인 인구 사이의 상관관계: 0.01
# 노인 비율 와 노인 인구 사이의 상관관계: 0.08
# 유동인구 와 노인 인구 사이의 상관관계: -0.10
# 공원 와 노인 인구 사이의 상관관계: -0.11
# 무인 단속 CCTV 와 노인 인구 사이의 상관관계: 0.14
# 불법주정차 단속건수 와 노인 인구 사이의 상관관계: -0.01
# 사망 건수 와 노인 인구 사이의 상관관계: -0.02
# 횡단보도 와 노인 인구 사이의 상관관계: 0.14
# 교통안전지표 와 노인 인구 사이의 상관관계: 0.07
# 노인 인구 와 어린이 비율 사이의 상관관계: 0.17
# 공원 와 어린이 비율 사이의 상관관계: -0.13
# 노인장애인보호구역 와 어린이 비율 사이의 상관관계: -0.09
# 주차장 와 어린이 비율 사이의 상관관계: 0.05
# CCTV 총합 와 어린이 비율 사이의 상관관계: 0.12
# 사망 건수 와 어린이 비율 사이의 상관관계: 0.15
# 사고 건수 와 어린이 비율 사이의 상관관계: 0.13
# 노인 인구 와 장애인 비율 사이의 상관관계: 0.01
# 학교(전체) 와 장애인 비율 사이의 상관관계: 0.18
# 주점 와 장애인 비율 사이의 상관관계: -0.15
# 다중이용시설 와 장애인 비율 사이의 상관관계: 0.08
# 옐로카펫 와 장애인 비율 사이의 상관관계: 0.19
# 지역아동센터 와 장애인 비율 사이의 상관관계: -0.10
# 공원 와 장애인 비율 사이의 상관관계: 0.06
# 노인장애인보호구역 와 장애인 비율 사이의 상관관계: 0.05
# 무인 단속 CCTV 와 장애인 비율 사이의 상관관계: -0.00
# 불법주정차 단속건수 와 장애인 비율 사이의 상관관계: 0.05
# 사망 건수 와 장애인 비율 사이의 상관관계: 0.03
# 사고 건수 와 장애인 비율 사이의 상관관계: -0.05
# 횡단보도 와 장애인 비율 사이의 상관관계: 0.15
# 노인 인구 와 노인 비율 사이의 상관관계: 0.08
# 학교(전체) 와 노인 비율 사이의 상관관계: 0.01
# 주점 와 노인 비율 사이의 상관관계: -0.20
# 옐로카펫 와 노인 비율 사이의 상관관계: 0.05
# 공원 와 노인 비율 사이의 상관관계: -0.09
# 노인장애인보호구역 와 노인 비율 사이의 상관관계: -0.03
# 노인 인구 와 유동인구 사이의 상관관계: -0.10
# 학교(전체) 와 유동인구 사이의 상관관계: 0.05
# 공동주택 와 유동인구 사이의 상관관계: -0.17
# 다중이용시설 와 유동인구 사이의 상관관계: 0.04
# 옐로카펫 와 유동인구 사이의 상관관계: 0.05
# 지역아동센터 와 유동인구 사이의 상관관계: 0.02
# 공원 와 유동인구 사이의 상관관계: -0.19
# 어린이보호구역 와 유동인구 사이의 상관관계: -0.14
# 무인 단속 CCTV 와 유동인구 사이의 상관관계: 0.06
# 불법주정차 단속건수 와 유동인구 사이의 상관관계: -0.02
# 사망 건수 와 유동인구 사이의 상관관계: 0.05
# 사고 건수 와 유동인구 사이의 상관관계: -0.01
# 횡단보도 와 유동인구 사이의 상관관계: -0.18
# 장애인 비율 와 학교(전체) 사이의 상관관계: 0.18
# 노인 비율 와 학교(전체) 사이의 상관관계: 0.01
# 유동인구 와 학교(전체) 사이의 상관관계: 0.05
# 주점 와 학교(전체) 사이의 상관관계: -0.19
# 공원 와 학교(전체) 사이의 상관관계: -0.16
# 주차장 와 학교(전체) 사이의 상관관계: -0.20
# CCTV 총합 와 학교(전체) 사이의 상관관계: -0.06
# 사망 건수 와 학교(전체) 사이의 상관관계: 0.04
# 사고 건수 와 학교(전체) 사이의 상관관계: 0.18
# 교통안전지표 와 학교(전체) 사이의 상관관계: -0.11
# 주점 와 유아시설 사이의 상관관계: -0.04
# 공원 와 유아시설 사이의 상관관계: 0.07
# 주차장 와 유아시설 사이의 상관관계: 0.16
# 사망 건수 와 유아시설 사이의 상관관계: 0.12
# 어린이 인구 와 주점 사이의 상관관계: -0.01
# 장애인 인구 와 주점 사이의 상관관계: 0.19
# 장애인 비율 와 주점 사이의 상관관계: -0.15
# 노인 비율 와 주점 사이의 상관관계: -0.20
# 학교(전체) 와 주점 사이의 상관관계: -0.19
# 유아시설 와 주점 사이의 상관관계: -0.04
# 다중이용시설 와 주점 사이의 상관관계: 0.03
# 옐로카펫 와 주점 사이의 상관관계: 0.03
# 공원 와 주점 사이의 상관관계: -0.11
# 노인장애인보호구역 와 주점 사이의 상관관계: 0.15
# 어린이보호구역 와 주점 사이의 상관관계: -0.06
# 무인 단속 CCTV 와 주점 사이의 상관관계: -0.03
# 불법주정차 단속건수 와 주점 사이의 상관관계: 0.16
# 사망 건수 와 주점 사이의 상관관계: 0.01
# 횡단보도 와 주점 사이의 상관관계: 0.07
# 교통안전지표 와 주점 사이의 상관관계: 0.16
# 장애인 인구 와 공동주택 사이의 상관관계: -0.07
# 유동인구 와 공동주택 사이의 상관관계: -0.17
# 지역아동센터 와 공동주택 사이의 상관관계: 0.09
# 노인장애인보호구역 와 공동주택 사이의 상관관계: -0.07
# CCTV 총합 와 공동주택 사이의 상관관계: -0.05
# 불법주정차 단속건수 와 공동주택 사이의 상관관계: -0.09
# 사고 건수 와 공동주택 사이의 상관관계: 0.13
# 횡단보도 와 공동주택 사이의 상관관계: 0.17
# 장애인 비율 와 다중이용시설 사이의 상관관계: 0.08
# 유동인구 와 다중이용시설 사이의 상관관계: 0.04
# 주점 와 다중이용시설 사이의 상관관계: 0.03
# 공원 와 다중이용시설 사이의 상관관계: -0.15
# 노인장애인보호구역 와 다중이용시설 사이의 상관관계: 0.13
# 주차장 와 다중이용시설 사이의 상관관계: 0.10
# 교통안전지표 와 다중이용시설 사이의 상관관계: 0.16
# 장애인 비율 와 옐로카펫 사이의 상관관계: 0.19
# 노인 비율 와 옐로카펫 사이의 상관관계: 0.05
# 유동인구 와 옐로카펫 사이의 상관관계: 0.05
# 주점 와 옐로카펫 사이의 상관관계: 0.03
# 공원 와 옐로카펫 사이의 상관관계: -0.03
# 주차장 와 옐로카펫 사이의 상관관계: -0.03
# CCTV 총합 와 옐로카펫 사이의 상관관계: 0.13
# 불법주정차 단속건수 와 옐로카펫 사이의 상관관계: 0.16
# 사망 건수 와 옐로카펫 사이의 상관관계: 0.06
# 교통안전지표 와 옐로카펫 사이의 상관관계: -0.11
# 장애인 비율 와 지역아동센터 사이의 상관관계: -0.10
# 유동인구 와 지역아동센터 사이의 상관관계: 0.02
# 공동주택 와 지역아동센터 사이의 상관관계: 0.09
# 사망 건수 와 지역아동센터 사이의 상관관계: -0.02
# 횡단보도 와 지역아동센터 사이의 상관관계: 0.14
# 교통안전지표 와 지역아동센터 사이의 상관관계: 0.17
# 어린이 인구 와 공원 사이의 상관관계: -0.01
# 장애인 인구 와 공원 사이의 상관관계: 0.07
# 노인 인구 와 공원 사이의 상관관계: -0.11
# 어린이 비율 와 공원 사이의 상관관계: -0.13
# 장애인 비율 와 공원 사이의 상관관계: 0.06
# 노인 비율 와 공원 사이의 상관관계: -0.09
# 유동인구 와 공원 사이의 상관관계: -0.19
# 학교(전체) 와 공원 사이의 상관관계: -0.16
# 유아시설 와 공원 사이의 상관관계: 0.07
# 주점 와 공원 사이의 상관관계: -0.11
# 다중이용시설 와 공원 사이의 상관관계: -0.15
# 옐로카펫 와 공원 사이의 상관관계: -0.03
# CCTV 총합 와 공원 사이의 상관관계: 0.10
# 불법주정차 단속건수 와 공원 사이의 상관관계: -0.04
# 사고 건수 와 공원 사이의 상관관계: -0.12
# 어린이 인구 와 노인장애인보호구역 사이의 상관관계: 0.02
# 어린이 비율 와 노인장애인보호구역 사이의 상관관계: -0.09
# 장애인 비율 와 노인장애인보호구역 사이의 상관관계: 0.05
# 노인 비율 와 노인장애인보호구역 사이의 상관관계: -0.03
# 주점 와 노인장애인보호구역 사이의 상관관계: 0.15
# 공동주택 와 노인장애인보호구역 사이의 상관관계: -0.07
# 다중이용시설 와 노인장애인보호구역 사이의 상관관계: 0.13
# 무인 단속 CCTV 와 노인장애인보호구역 사이의 상관관계: -0.08
# 불법주정차 단속건수 와 노인장애인보호구역 사이의 상관관계: -0.18
# 사망 건수 와 노인장애인보호구역 사이의 상관관계: 0.06
# 횡단보도 와 노인장애인보호구역 사이의 상관관계: -0.02
# 유동인구 와 어린이보호구역 사이의 상관관계: -0.14
# 주점 와 어린이보호구역 사이의 상관관계: -0.06
# 불법주정차 단속건수 와 어린이보호구역 사이의 상관관계: -0.02
# 사망 건수 와 어린이보호구역 사이의 상관관계: 0.18
# 교통안전지표 와 어린이보호구역 사이의 상관관계: -0.10
# 어린이 인구 와 주차장 사이의 상관관계: 0.16
# 장애인 인구 와 주차장 사이의 상관관계: -0.07
# 어린이 비율 와 주차장 사이의 상관관계: 0.05
# 학교(전체) 와 주차장 사이의 상관관계: -0.20
# 유아시설 와 주차장 사이의 상관관계: 0.16
# 다중이용시설 와 주차장 사이의 상관관계: 0.10
# 옐로카펫 와 주차장 사이의 상관관계: -0.03
# 무인 단속 CCTV 와 주차장 사이의 상관관계: -0.15
# 불법주정차 단속건수 와 주차장 사이의 상관관계: 0.19
# 사망 건수 와 주차장 사이의 상관관계: -0.14
# 횡단보도 와 주차장 사이의 상관관계: -0.17
# 노인 인구 와 무인 단속 CCTV 사이의 상관관계: 0.14
# 장애인 비율 와 무인 단속 CCTV 사이의 상관관계: -0.00
# 유동인구 와 무인 단속 CCTV 사이의 상관관계: 0.06
# 주점 와 무인 단속 CCTV 사이의 상관관계: -0.03
# 노인장애인보호구역 와 무인 단속 CCTV 사이의 상관관계: -0.08
# 주차장 와 무인 단속 CCTV 사이의 상관관계: -0.15
# CCTV 총합 와 무인 단속 CCTV 사이의 상관관계: 0.13
# 교통안전지표 와 무인 단속 CCTV 사이의 상관관계: -0.15
# 어린이 비율 와 CCTV 총합 사이의 상관관계: 0.12
# 학교(전체) 와 CCTV 총합 사이의 상관관계: -0.06
# 공동주택 와 CCTV 총합 사이의 상관관계: -0.05
# 옐로카펫 와 CCTV 총합 사이의 상관관계: 0.13
# 공원 와 CCTV 총합 사이의 상관관계: 0.10
# 무인 단속 CCTV 와 CCTV 총합 사이의 상관관계: 0.13
# 횡단보도 와 CCTV 총합 사이의 상관관계: 0.20
# 노인 인구 와 불법주정차 단속건수 사이의 상관관계: -0.01
# 장애인 비율 와 불법주정차 단속건수 사이의 상관관계: 0.05
# 유동인구 와 불법주정차 단속건수 사이의 상관관계: -0.02
# 주점 와 불법주정차 단속건수 사이의 상관관계: 0.16
# 공동주택 와 불법주정차 단속건수 사이의 상관관계: -0.09
# 옐로카펫 와 불법주정차 단속건수 사이의 상관관계: 0.16
# 공원 와 불법주정차 단속건수 사이의 상관관계: -0.04
# 노인장애인보호구역 와 불법주정차 단속건수 사이의 상관관계: -0.18
# 어린이보호구역 와 불법주정차 단속건수 사이의 상관관계: -0.02
# 주차장 와 불법주정차 단속건수 사이의 상관관계: 0.19
# 사망 건수 와 불법주정차 단속건수 사이의 상관관계: 0.14
# 교통안전지표 와 불법주정차 단속건수 사이의 상관관계: 0.02
# 어린이 인구 와 사망 건수 사이의 상관관계: 0.19
# 장애인 인구 와 사망 건수 사이의 상관관계: 0.16
# 노인 인구 와 사망 건수 사이의 상관관계: -0.02
# 어린이 비율 와 사망 건수 사이의 상관관계: 0.15
# 장애인 비율 와 사망 건수 사이의 상관관계: 0.03
# 유동인구 와 사망 건수 사이의 상관관계: 0.05
# 학교(전체) 와 사망 건수 사이의 상관관계: 0.04
# 유아시설 와 사망 건수 사이의 상관관계: 0.12
# 주점 와 사망 건수 사이의 상관관계: 0.01
# 옐로카펫 와 사망 건수 사이의 상관관계: 0.06
# 지역아동센터 와 사망 건수 사이의 상관관계: -0.02
# 노인장애인보호구역 와 사망 건수 사이의 상관관계: 0.06
# 어린이보호구역 와 사망 건수 사이의 상관관계: 0.18
# 주차장 와 사망 건수 사이의 상관관계: -0.14
# 불법주정차 단속건수 와 사망 건수 사이의 상관관계: 0.14
# 횡단보도 와 사망 건수 사이의 상관관계: 0.16
# 어린이 비율 와 사고 건수 사이의 상관관계: 0.13
# 장애인 비율 와 사고 건수 사이의 상관관계: -0.05
# 유동인구 와 사고 건수 사이의 상관관계: -0.01
# 학교(전체) 와 사고 건수 사이의 상관관계: 0.18
# 공동주택 와 사고 건수 사이의 상관관계: 0.13
# 공원 와 사고 건수 사이의 상관관계: -0.12
# 노인 인구 와 횡단보도 사이의 상관관계: 0.14
# 장애인 비율 와 횡단보도 사이의 상관관계: 0.15
# 유동인구 와 횡단보도 사이의 상관관계: -0.18
# 주점 와 횡단보도 사이의 상관관계: 0.07
# 공동주택 와 횡단보도 사이의 상관관계: 0.17
# 지역아동센터 와 횡단보도 사이의 상관관계: 0.14
# 노인장애인보호구역 와 횡단보도 사이의 상관관계: -0.02
# 주차장 와 횡단보도 사이의 상관관계: -0.17
# CCTV 총합 와 횡단보도 사이의 상관관계: 0.20
# 사망 건수 와 횡단보도 사이의 상관관계: 0.16
# 장애인 인구 와 교통안전지표 사이의 상관관계: 0.10
# 노인 인구 와 교통안전지표 사이의 상관관계: 0.07
# 학교(전체) 와 교통안전지표 사이의 상관관계: -0.11
# 주점 와 교통안전지표 사이의 상관관계: 0.16
# 다중이용시설 와 교통안전지표 사이의 상관관계: 0.16
# 옐로카펫 와 교통안전지표 사이의 상관관계: -0.11
# 지역아동센터 와 교통안전지표 사이의 상관관계: 0.17
# 어린이보호구역 와 교통안전지표 사이의 상관관계: -0.10
# 무인 단속 CCTV 와 교통안전지표 사이의 상관관계: -0.15
# 불법주정차 단속건수 와 교통안전지표 사이의 상관관계: 0.02

# %%
import pandas as pd

file_path = '/Users/raekkkky/Desktop/DNA/[24 1학기] 🏆승승장구/강서_최종 제출/데이터/최종 데이터프레임.csv'
df = pd.read_csv(file_path)

# "교통안전지표"와 다른 모든 변수들 간의 상관관계 계산
correlation_matrix = df.corr()

# 상관계수의 절대값이 0.2보다 작은 "교통안전지표"와 다른 변수들 간의 상관관계만 출력
for column in correlation_matrix.columns.drop('교통안전지표'):
    correlation = correlation_matrix.at[column, '교통안전지표']
    if abs(correlation) < 0.2:
        print(f'"{column}"와 "교통안전지표" 변수와의 상관관계는 {correlation:.2f}이다.')
# Out:
# "장애인 인구"와 "교통안전지표" 변수와의 상관관계는 0.10이다.
# "노인 인구"와 "교통안전지표" 변수와의 상관관계는 0.07이다.
# "학교(전체)"와 "교통안전지표" 변수와의 상관관계는 -0.11이다.
# "주점"와 "교통안전지표" 변수와의 상관관계는 0.16이다.
# "다중이용시설"와 "교통안전지표" 변수와의 상관관계는 0.16이다.
# "옐로카펫"와 "교통안전지표" 변수와의 상관관계는 -0.11이다.
# "지역아동센터"와 "교통안전지표" 변수와의 상관관계는 0.17이다.
# "어린이보호구역"와 "교통안전지표" 변수와의 상관관계는 -0.10이다.
# "무인 단속 CCTV"와 "교통안전지표" 변수와의 상관관계는 -0.15이다.
# "불법주정차 단속건수"와 "교통안전지표" 변수와의 상관관계는 0.02이다.
# /var/folders/cx/r_wdv_3d2q7_cr1m0yrq3dph0000gn/T/ipykernel_8802/4152684539.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# # 군집화

# %%
# [0] 필요한 라이브러리 임포트

import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import random, warnings
warnings.filterwarnings("ignore")

# 기본 시각화 라이브러리 임포트
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns 
from matplotlib import rc
rc("font", family="AppleGothic")
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "iframe"
plt.rcParams['axes.unicode_minus'] = False

# 스케일링.. 등
from sklearn.preprocessing import StandardScaler
from category_encoders.ordinal import OrdinalEncoder
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# 데이터 가져오기
train = pd.read_csv('/Users/raekkkky/Desktop/DNA/[24 1학기] 🏆승승장구/5주차/최종 데이터프레임.csv', encoding='euc-kr', thousands=',')
train.shape
# Out:
# (20, 33)

# %%
train.head()
# Out:
#     행정동  옐로카펫  유아시설  지역아동센터  학교(전체)  어린이 인구  전체 인구  장애인 인구  어린이 비율   노인 비율  \
# 0   염창동     2    30       1       5    7791  41326    1065  0.1885  0.1179
# 1  등촌1동     0    13       0       1    2375  24888     735  0.0954  0.1296
# 2  등촌2동     1    13       0       6    2372  19417     719  0.1222  0.1813
# 3  등촌3동     4    21       2      12    3047  29554    3649  0.1031  0.2518
# 4  화곡본동     2    27       2       4    3596  33130    1390  0.1085  0.1624
#
#    장애인 비율  공원 수  주차장 개수  따릉이 대여소 개수  노인장애인보호구역  노인 인구  주점 개수  공동주택  차량_등록대수  \
# 0  0.0258     1     429          11          0   4872      5    53    15584
# 1  0.0295     1     493           8          1   3226      6    29     9043
# 2  0.0370     0     849           5          0   3520      0     9     7002
# 3  0.1235     0     235           8          2   7442      1    18     9151
# 4  0.0420     1    2041           4          2   5379      4     1     9189
#
#    대규모점포  다중이용시설  무인 단속 카메라  유동인구 수  CCTV 총합  과속방지턱  불법주정차 단속건수  교통사고 사망건수  \
# 0      3       4          9  516208      160    178        7495          9
# 1      1       2          3  512031      107     85        6341          4
# 2      0       1          2  265281      128     80        1888          0
# 3      2       6          5  891296      112     64        2824          2
# 4      1       1          3  437735      357    124        4098          1
#
#    사고 건수  버스 정류장 개수  횡단보도 수  행정동 면적  시설물 개수  교통안전지표
# 0    265         36      14    1.74     916  0.0715
# 1    133         15      17    0.64     870  0.0615
# 2    129          9       3    0.92     392  0.0737
# 3    217         47      45    0.79    1165  0.0962
# 4    238         25       6    0.98     755  0.1043

# %%
train
# Out:
#      행정동  옐로카펫  유아시설  지역아동센터  학교(전체)  어린이 인구  전체 인구  장애인 인구  어린이 비율   노인 비율  \
# 0    염창동     2    30       1       5    7791  41326    1065  0.1885  0.1179
# 1   등촌1동     0    13       0       1    2375  24888     735  0.0954  0.1296
# 2   등촌2동     1    13       0       6    2372  19417     719  0.1222  0.1813
# 3   등촌3동     4    21       2      12    3047  29554    3649  0.1031  0.2518
# 4   화곡본동     2    27       2       4    3596  33130    1390  0.1085  0.1624
# 5   화곡1동     2    21       3       3    4169  51261    2093  0.0813  0.1776
# 6   화곡2동     1    11       0       1    2087  17198     772  0.1214  0.1834
# 7   화곡3동     0    12       0       0    2561  21252     828  0.1205  0.2118
# 8   화곡4동     1    15       1       4    2037  19846     984  0.1026  0.2119
# 9   화곡6동     2    12       1       3    2811  24742     990  0.1136  0.1773
# 10  화곡8동     0    17       1       0    2343  23597    1018  0.0993  0.2002
# 11  우장산동     1    28       1       1    8540  43811     779  0.1949  0.1495
# 12  가양1동     1    25       0       3    3011  33992    2422  0.0886  0.1031
# 13  가양2동     1     9       0       3     813  13520    1617  0.0601  0.3366
# 14  가양3동     1    14       0       3    1026  14232    1515  0.0721  0.2764
# 15  발산1동     3    33       1      15    7186  35744    1312  0.2010  0.1519
# 16   공항동     2    21       3       5    5068  29747    1798  0.1704  0.1507
# 17  방화1동     3    37       3       7    7397  42248    1588  0.1751  0.1736
# 18  방화2동     1    14       1       2    2249  22759    1987  0.0988  0.2283
# 19  방화3동     3    15       0       6    2415  22075    1246  0.1094  0.2612
#
#     장애인 비율  공원 수  주차장 개수  따릉이 대여소 개수  노인장애인보호구역  노인 인구  주점 개수  공동주택  차량_등록대수  \
# 0   0.0258     1     429          11          0   4872      5    53    15584
# 1   0.0295     1     493           8          1   3226      6    29     9043
# 2   0.0370     0     849           5          0   3520      0     9     7002
# 3   0.1235     0     235           8          2   7442      1    18     9151
# 4   0.0420     1    2041           4          2   5379      4     1     9189
# 5   0.0408     0    2720           7          1   9102    121     7    15923
# 6   0.0449     0    1138           1          0   3154      1     6     4913
# 7   0.0390     0     872           3          1   4502     12    12     6410
# 8   0.0496     0    1484           1          0   4205      6    10     6019
# 9   0.0400     0    1232           4          1   4386     62     9     7906
# 10  0.0431     0    1417           1          1   4725     10     5     6254
# 11  0.0178     1     987          10          0   6551      4    33    14011
# 12  0.0713     2     515          44          0   3504     37    13    25761
# 13  0.1196     1      44           4          0   4551      2     6     4306
# 14  0.1065     0      41           5          0   3934      0    10     6300
# 15  0.0367     0     817          27          1   5431      0    26    13965
# 16  0.0604     0    1499          19          0   4484      9     7    10360
# 17  0.0376     0    1095          15          1   7333      0    40    15268
# 18  0.0873     1    1224           7          1   5197      6    21     9851
# 19  0.0564     2     255           5          0   5766      0    16     7566
#
#     대규모점포  다중이용시설  무인 단속 카메라   유동인구 수  CCTV 총합  과속방지턱  불법주정차 단속건수  교통사고 사망건수  \
# 0       3       4          9   516208      160    178        7495          9
# 1       1       2          3   512031      107     85        6341          4
# 2       0       1          2   265281      128     80        1888          0
# 3       2       6          5   891296      112     64        2824          2
# 4       1       1          3   437735      357    124        4098          1
# 5       3       3          3   697732      356    114       13410          2
# 6       0       1          1   191641      138     85        3829          1
# 7       2       0          2   372210      128     74        4245          2
# 8       1       1          1   267043      208    103        5120          0
# 9       1       2          5   473330      190    102        5820          2
# 10      0       0          1   783919      151     93        3628          0
# 11      0       2          3   482357      204    107        3073          0
# 12      4       2          6  1134834      267     66       16889          3
# 13      1       2          3   278465       29     22       13315          2
# 14      0       1          2   220502       47     22        1801          0
# 15      2      15          8   669971      175    105       20476          3
# 16      1      16         11   719295      215     78       41748          2
# 17      3       3          5   451722      221    176        6578          1
# 18      3       6          5   629424      321    175        7404          9
# 19      0       0          7   270467      106    100        2714          2
#
#     사고 건수  버스 정류장 개수  횡단보도 수  행정동 면적  시설물 개수  교통안전지표
# 0     265         36      14    1.74     916  0.0715
# 1     133         15      17    0.64     870  0.0615
# 2     129          9       3    0.92     392  0.0737
# 3     217         47      45    0.79    1165  0.0962
# 4     238         25       6    0.98     755  0.1043
# 5     460         27      33    1.12    1605  0.1163
# 6     121         28       4    0.45     424  0.0997
# 7     132          9       7    0.53     727  0.0842
# 8     182         31       5    0.82     758  0.1210
# 9     255         29      11    1.11    1062  0.1305
# 10    195         26       6    0.53     654  0.1247
# 11    183         27      19    1.36     837  0.0522
# 12    177         58     127    4.70    3087  0.0282
# 13    127         12      18    1.00     235  0.1208
# 14    103         17      22    0.50     201  0.0654
# 15    341         65     112    2.94    1859  0.0990
# 16    233         60      60   10.87     966  0.0911
# 17    202         43      56    1.48    1233  0.0533
# 18    504         35      35    6.41     960  0.2101
# 19     84         20      50    2.55     283  0.0460

# %%
train.drop(['행정동'], axis=1, inplace=True)
train.shape
# Out:
# (20, 32)

# %%
# 군집화 개수 찾기 및 군집 평가하기! (목적변수도 포함해서 진행 - 전략 기획을 위해서!)

# 1. Elbow Method로 K를 구하기!

# SSE 계산을 위한 리스트
sse = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(train)
    sse.append(kmeans.inertia_)

# 엘보우 메서드 그래프
plt.plot(range(1, 11), sse, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('SSE')
plt.show()

# %%
from sklearn.metrics import silhouette_score

sil_scores = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(train)
    sil_score = silhouette_score(train, kmeans.labels_)
    sil_scores.append(sil_score)

# 실루엣 분석 그래프
plt.plot(range(2, 11), sil_scores, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
# 누적된 설명된 분산 그래프를 보고 PCA 주성분 수 결정하기!

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# train_df를 특정 열로만 구성된 NumPy 배열로 변환
# 필요에 따라 특정 열만 선택하여 X에 할당
X = train.values

# 데이터를 표준화 (Standardization)
scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)

# PCA 모델 생성
pca = PCA()
X_pca = pca.fit_transform(X_standardized)

# 누적된 설명된 분산 시각화
explained_variance_ratio_cumsum = pca.explained_variance_ratio_.cumsum()

plt.plot(range(1, len(explained_variance_ratio_cumsum) + 1), explained_variance_ratio_cumsum, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance vs. Number of Principal Components')
plt.show()

# %%
# 차원축소
##### 1. 데이터 형태가 어떻게 되어있을지 시각적으로 확인하기 위해 차원축소 적용 (2, 3차원)
##### 2. PCA를 가장 잘 알고 있기에 설명하기도 편해서 PCA 사용!
##### 3. 최대한 정보의 손실을 줄이기 위해서 정보가 얼마나 줄었는지도 확인하기!

pca = PCA(n_components=2)
pca_result = pca.fit_transform(train)

# PCA 결과를 데이터프레임에 추가
train_pca = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
train_final = pd.concat([train, train_pca], axis=1)

# PCA 주성분별 설명된 분산의 비율 출력
explained_variance_ratio = pca.explained_variance_ratio_
print("Explained Variance Ratio:")
print("PC1:", explained_variance_ratio[0])
print("PC2:", explained_variance_ratio[1])
# Out:
# Explained Variance Ratio:
# PC1: 0.9971274157349375
# PC2: 0.0015450771479986762

# %%
# 2차원 산점도 시각화
import plotly.express as px

fig = px.scatter(train_final, x='PC1', y='PC2')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_60.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# 차원축소를 적용한 데이터로 군집화 후 시각화!

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# K-means 군집화를 위해 PCA 적용
pca = PCA(n_components=2)
pca_result = pca.fit_transform(train)

# PCA 결과를 데이터프레임에 추가
train_pca = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
train_final = pd.concat([train, train_pca], axis=1)

# K-means 군집화
kmeans = KMeans(n_clusters=4, random_state=42).fit(train_pca[['PC1', 'PC2']])

# 군집 결과를 데이터프레임에 추가
train_final['cluster'] = kmeans.labels_

# K-means 군집 결과 시각화
fig_cluster = px.scatter(train_final, x='PC1', y='PC2', color='cluster', title='K-means Clustering')
fig_cluster.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_61.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
import numpy as np

# K-means 군집화 결과에 대한 실루엣 계수 계산
silhouette_values = silhouette_samples(train_pca[['PC1', 'PC2']], kmeans.labels_)

# 데이터프레임에 실루엣 계수 추가
train_final['silhouette'] = silhouette_values

# 시각화
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# 실루엣 플롯
y_lower = 10
for i in range(4):  # 군집의 수에 따라 조절
    ith_cluster_silhouette_values = silhouette_values[train_final['cluster'] == i]
    ith_cluster_silhouette_values.sort()

    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = plt.cm.nipy_spectral(float(i) / 4)
    ax1.fill_betweenx(np.arange(y_lower, y_upper),
                      0, ith_cluster_silhouette_values,
                      facecolor=color, edgecolor=color, alpha=0.7)

    ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
    y_lower = y_upper + 10

ax1.set_title("실루엣 플롯")
ax1.set_xlabel("실루엣 계수 값")
ax1.set_ylabel("군집")

# 전체 실루엣 계수 평균 플롯
silhouette_avg = silhouette_score(train_pca[['PC1', 'PC2']], kmeans.labels_)
ax2.axvline(x=silhouette_avg, color="red", linestyle="--")
ax2.set_yticks([])  # y 축 레이블 제거
ax2.set_xlim([-0.1, 1])
ax2.set_title("전체 실루엣 계수 평균: {:.2f}".format(silhouette_avg))

plt.show()

# %%
train = pd.read_csv('/Users/raekkkky/Desktop/DNA/[24 1학기] 🏆승승장구/5주차/최종 데이터프레임.csv', encoding='euc-kr', thousands=',')
train.drop(['행정동'], axis=1, inplace=True)
# 차원축소
##### 1. 데이터 형태가 어떻게 되어있을지 시각적으로 확인하기 위해 차원축소 적용 (2, 3차원)
##### 2. PCA를 가장 잘 알고 있기에 설명하기도 편해서 PCA 사용!
##### 3. 최대한 정보의 손실을 줄이기 위해서 정보가 얼마나 줄었는지도 확인하기!

# 차원축소를 적용한 데이터로 군집화 후 시각화!

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# K-means 군집화를 위해 PCA 적용
pca = PCA(n_components=2)
pca_result = pca.fit_transform(train)

# PCA 결과를 데이터프레임에 추가
train_pca = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
train_final = pd.concat([train, train_pca], axis=1)

# K-means 군집화
kmeans = KMeans(n_clusters=3, random_state=42).fit(train_pca[['PC1', 'PC2']])

# 군집 결과를 데이터프레임에 추가
train_final['cluster'] = kmeans.labels_

# K-means 군집 결과 시각화
fig_cluster = px.scatter(train_final, x='PC1', y='PC2', color='cluster', title='K-means Clustering')
fig_cluster.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_68.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
train_final
# Out:
#     옐로카펫  유아시설  지역아동센터  학교(전체)  어린이 인구  전체 인구  장애인 인구  어린이 비율   노인 비율  장애인 비율  \
# 0      2    30       1       5    7791  41326    1065  0.1885  0.1179  0.0258
# 1      0    13       0       1    2375  24888     735  0.0954  0.1296  0.0295
# 2      1    13       0       6    2372  19417     719  0.1222  0.1813  0.0370
# 3      4    21       2      12    3047  29554    3649  0.1031  0.2518  0.1235
# 4      2    27       2       4    3596  33130    1390  0.1085  0.1624  0.0420
# 5      2    21       3       3    4169  51261    2093  0.0813  0.1776  0.0408
# 6      1    11       0       1    2087  17198     772  0.1214  0.1834  0.0449
# 7      0    12       0       0    2561  21252     828  0.1205  0.2118  0.0390
# 8      1    15       1       4    2037  19846     984  0.1026  0.2119  0.0496
# 9      2    12       1       3    2811  24742     990  0.1136  0.1773  0.0400
# 10     0    17       1       0    2343  23597    1018  0.0993  0.2002  0.0431
# 11     1    28       1       1    8540  43811     779  0.1949  0.1495  0.0178
# 12     1    25       0       3    3011  33992    2422  0.0886  0.1031  0.0713
# 13     1     9       0       3     813  13520    1617  0.0601  0.3366  0.1196
# 14     1    14       0       3    1026  14232    1515  0.0721  0.2764  0.1065
# 15     3    33       1      15    7186  35744    1312  0.2010  0.1519  0.0367
# 16     2    21       3       5    5068  29747    1798  0.1704  0.1507  0.0604
# 17     3    37       3       7    7397  42248    1588  0.1751  0.1736  0.0376
# 18     1    14       1       2    2249  22759    1987  0.0988  0.2283  0.0873
# 19     3    15       0       6    2415  22075    1246  0.1094  0.2612  0.0564
#
#     공원 수  주차장 개수  따릉이 대여소 개수  노인장애인보호구역  노인 인구  주점 개수  공동주택  차량_등록대수  대규모점포  \
# 0      1     429          11          0   4872      5    53    15584      3
# 1      1     493           8          1   3226      6    29     9043      1
# 2      0     849           5          0   3520      0     9     7002      0
# 3      0     235           8          2   7442      1    18     9151      2
# 4      1    2041           4          2   5379      4     1     9189      1
# 5      0    2720           7          1   9102    121     7    15923      3
# 6      0    1138           1          0   3154      1     6     4913      0
# 7      0     872           3          1   4502     12    12     6410      2
# 8      0    1484           1          0   4205      6    10     6019      1
# 9      0    1232           4          1   4386     62     9     7906      1
# 10     0    1417           1          1   4725     10     5     6254      0
# 11     1     987          10          0   6551      4    33    14011      0
# 12     2     515          44          0   3504     37    13    25761      4
# 13     1      44           4          0   4551      2     6     4306      1
# 14     0      41           5          0   3934      0    10     6300      0
# 15     0     817          27          1   5431      0    26    13965      2
# 16     0    1499          19          0   4484      9     7    10360      1
# 17     0    1095          15          1   7333      0    40    15268      3
# 18     1    1224           7          1   5197      6    21     9851      3
# 19     2     255           5          0   5766      0    16     7566      0
#
#     다중이용시설  무인 단속 카메라   유동인구 수  CCTV 총합  과속방지턱  불법주정차 단속건수  교통사고 사망건수  사고 건수  \
# 0        4          9   516208      160    178        7495          9    265
# 1        2          3   512031      107     85        6341          4    133
# 2        1          2   265281      128     80        1888          0    129
# 3        6          5   891296      112     64        2824          2    217
# 4        1          3   437735      357    124        4098          1    238
# 5        3          3   697732      356    114       13410          2    460
# 6        1          1   191641      138     85        3829          1    121
# 7        0          2   372210      128     74        4245          2    132
# 8        1          1   267043      208    103        5120          0    182
# 9        2          5   473330      190    102        5820          2    255
# 10       0          1   783919      151     93        3628          0    195
# 11       2          3   482357      204    107        3073          0    183
# 12       2          6  1134834      267     66       16889          3    177
# 13       2          3   278465       29     22       13315          2    127
# 14       1          2   220502       47     22        1801          0    103
# 15      15          8   669971      175    105       20476          3    341
# 16      16         11   719295      215     78       41748          2    233
# 17       3          5   451722      221    176        6578          1    202
# 18       6          5   629424      321    175        7404          9    504
# 19       0          7   270467      106    100        2714          2     84
#
#     버스 정류장 개수  횡단보도 수  행정동 면적  시설물 개수  교통안전지표            PC1           PC2  \
# 0          36      14    1.74     916  0.0715    3270.528902  14245.716426
# 1          15      17    0.64     870  0.0615   -1371.682885  -4061.189396
# 2           9       3    0.92     392  0.0737 -248224.111383  -3863.852456
# 3          47      45    0.79    1165  0.0962  377777.764539  -9179.737665
# 4          25       6    0.98     755  0.1043  -75489.859088   5787.410509
# 5          27      33    1.12    1605  0.1163  185020.492220  19345.318314
# 6          28       4    0.45     424  0.0997 -321876.455703  -4515.096580
# 7           9       7    0.53     727  0.0842 -141273.347496  -4660.862157
# 8          31       5    0.82     758  0.1210 -246414.460370  -3426.805454
# 9          29      11    1.11    1062  0.1305  -40078.780246  -3360.195281
# 10         26       6    0.53     654  0.1247  270286.076330 -13058.227723
# 11         27      19    1.36     837  0.0522  -30603.292488  16857.037312
# 12         58     127    4.70    3087  0.0282  621756.019724  -5573.397453
# 13         12      18    1.00     235  0.1208 -235024.255282  -9495.399809
# 14         17      22    0.50     201  0.0654 -293102.940951  -8004.327773
# 15         65     112    2.94    1859  0.0990  157035.593056   5985.343898
# 16         60      60   10.87     966  0.0911  206495.369904   -168.367905
# 17         43      56    1.48    1233  0.0533  -61181.410785  16742.713014
# 18         35      35    6.41     960  0.2101  115958.695452  -8514.387937
# 19         20      50    2.55     283  0.0460 -242959.943448  -1081.691886
#
#     cluster
# 0         0
# 1         0
# 2         2
# 3         1
# 4         0
# 5         1
# 6         2
# 7         2
# 8         2
# 9         0
# 10        1
# 11        0
# 12        1
# 13        2
# 14        2
# 15        0
# 16        1
# 17        0
# 18        0
# 19        2

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
import numpy as np

# K-means 군집화 결과에 대한 실루엣 계수 계산
silhouette_values = silhouette_samples(train_pca[['PC1', 'PC2']], kmeans.labels_)

# 데이터프레임에 실루엣 계수 추가
train_final['silhouette'] = silhouette_values

# 시각화
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# 실루엣 플롯
y_lower = 10
for i in range(3):  # 군집의 수에 따라 조절
    ith_cluster_silhouette_values = silhouette_values[train_final['cluster'] == i]
    ith_cluster_silhouette_values.sort()

    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = plt.cm.nipy_spectral(float(i) / 3)
    ax1.fill_betweenx(np.arange(y_lower, y_upper),
                      0, ith_cluster_silhouette_values,
                      facecolor=color, edgecolor=color, alpha=0.7)

    ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
    y_lower = y_upper + 10

ax1.set_title("실루엣 플롯")
ax1.set_xlabel("실루엣 계수 값")
ax1.set_ylabel("군집")

# 전체 실루엣 계수 평균 플롯
silhouette_avg = silhouette_score(train_pca[['PC1', 'PC2']], kmeans.labels_)
ax2.axvline(x=silhouette_avg, color="red", linestyle="--")
ax2.set_yticks([])  # y 축 레이블 제거
ax2.set_xlim([-0.1, 1])
ax2.set_title("전체 실루엣 계수 평균: {:.2f}".format(silhouette_avg))

plt.show()

# %% [markdown]
# # 작업중

# %%
import pandas as pd

cctv_df = pd.read_csv('/Users/raekkkky/Desktop/DNA/[24 1학기] 🏆승승장구/5주차/최종 cctv 위경도.csv', encoding='utf-8-sig')
cctv_df.info()

import folium

cctv_df["위도"].mean()
cctv_df["경도"].mean()

map = folium.Map(location=[cctv_df["위도"].mean(),cctv_df["경도"].mean()], zoom_start=1)

for n in cctv_df.index:
    name = cctv_df.loc[n, "행정동"]
    address = cctv_df.loc[n, "주소"]
    popup = f"{name}-{address}"
    location = [cctv_df.loc[n, "위도"], cctv_df.loc[n, "경도"]]
    folium.Marker(
        location = location,
        popup = popup,
    ).add_to(map)
map
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주소      84 non-null     object
#  1   위도      84 non-null     float64
#  2   경도      84 non-null     float64
#  3   행정동     84 non-null     object
#  4   제한속도    84 non-null     int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 3.4+ KB
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_640fc7cf1609d96f7532c8a8cea84b13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_640fc7cf1609d96f7532c8a8cea84b13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_640fc7cf1609d96f7532c8a8cea84b13 = L.map(
#                 &quot;map_640fc7cf1609d96f7532c8a8cea84b13&quot;,
#                 {
#                     center: [37.55769451190476, 126.83634159523811],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d596fb26f4a38199de2790b9c4fd8ff = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_640fc7cf1609d96f7532c8a8cea84b13);
#
#
#             var marker_65f64023d7f059851941d773086741c5 = L.marker(
#                 [37.569088, 126.816603],
#                 {}
#             ).addTo(map_640fc7cf1609d96f7532c8a8cea84b13);
#
#
#         var popup_c7d3c6fbd87a405ddebb90cf78a3296b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31a29be0458905a9e3609d1a23168971 = $(`&lt;div id=&quot;html_31a29be0458905a9e3609d1a23168971&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;방화1동-서울특별시 강서구 방화대로 319&lt;/div&gt;`)[0];
#                 popup_c7d3c6fbd87a405ddebb90cf78a3296b.setContent(html_31a29be0458905a9e3609d1a23168971);
#
#
#
#         marker_65f64023d7f059851941d773086741c5.bindPopup(popup_c7d3c6fbd87a405ddebb90cf78a3296b)
#         ;
#
#
#
#
#             var marker_3cdea9576792d92152639ba0e79a250f = L.marker(
#                 [37.55532, 126.854341],
#                 {}
#             ).addTo(map_640fc7cf1609d96f7532c8a8cea84b13);
#
#
#         var popup_82e40a8a599e7976dd5b86161b3f2c3e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fcba07ffa3dde48017d5cd35a09cd3b8 = $(`&lt;div id=&quot;html_fcba07ffa3dde48017d5cd35a09cd3b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;등촌1동-서울특별시 강서구 공항대로 431&lt;/div&gt;`)[0];
#                 popup_82e40a8a599e7976dd5b86161b3f2c3e.setContent(html_fcba07ffa3dde48017d5cd35a09cd3b8);
#
#
#
#         marker_3cdea9576792d92152639ba0e79a250f.bindPopup(popup_82e40a8a599e7976dd5b86161b3f2c3e)
#         ;
#
#
#
#
#             var marker_e6274750b5e42f8fde5c49f4122264dc = L.marker(
#                 [37.561314, 126.810262],
#                 {}
#             ).addTo(map_640fc7cf1609d96f7532c8a8cea84b13);
#
#
#         var popup_211af1630112a6fac903ad982bc828d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6f1180d2a8622497bb4379f462c4538 = $(`&lt;div id=&quot;html_d6f1180d2a8622497bb4379f462c4538&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;공항동-서울특별시 강서구 공항동 53-44&lt;/div&gt;`)[0];
#                 popup_211af1630112a6fac903ad982bc828d8.setContent(html_d6f1180d2a8622497bb4379f462c4538);
#
#
#
#         marker_e6274750b5e42f8fde5c49f4122264dc.bindPopup(popup_211af1630112a6fac903ad982bc828d8)
#         ;
#
#
#
#
#             var marker_6e2af7bad0f6ed5b5ee6524c36f6a877 = L.marker(
#                 [37.53061, 126.847404],
#                 {}
#             ).addTo(map_640fc7cf1609d96f7532c8a8cea84b13);
#
#
#         var popup_7fcc8ec0fe93a2ad49d7659822a0d65d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8562c75afa8e7054ba7585f9dab5855 = $(`&lt;div id=&quot;html_e8562c75afa8e7054ba7585f9dab5855&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;화곡8동-서울특별시 강서구 강서로 34&lt;/div&gt;`)[0];
#                 popup_7fcc8ec0fe93a2ad49d7659822a0d65d.setContent(html_e8562c75afa8e7054ba7585f9dab5855);
#
#
#
#         marker_6e2af7bad0f6ed5b5ee6524c36f6a877.bindPopup(popup_7fcc8ec0fe93a2ad49d7659822a0d65d)
#         ;
#
#
#
#
#             var marker_f265392e3e3621cf1f692c1e72d3674d = L.marker(
#                 [37.582414, 126.81801],
#                 {}
#             ).addTo(map_640fc7cf1609d96f7532c8a8cea84b13);
#
#
#         var popup_b9a8adb10eae083a734fff050c20be72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c787e21c0c59e047e4a303b9524e26e9 = $(`&lt;div id=&quot;html_c787e21c0c59e047e4a303b9524e26e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;방화3동-서울특별시 강서구 방화동 산 116-9&lt;/div&gt;`)[0];
#                 popup_b9a8adb10eae083a734fff050c20be72.setContent(html_c787e21c0c59e047e4a303b9524e26e9);
#
#
#
#         marker_f265392e3e3621cf1f692c1e72d3674d.bindPopup(popup_b9a8adb10eae083a734fff050c20be72)
#         ;
#
#
#
#
#             var marker_b72c1b6221077810fdb235d3cda76481

# %%
# 위도는 y이고 경도는 x입니다!! 까먹을 수 있으니 인지하도록!!

import pandas as pd

cctv_df = pd.read_csv('/Users/raekkkky/Desktop/DNA/[24 1학기] 🏆승승장구/6주차/후보지 예시.csv', encoding='utf-8-sig')
cctv_df.head(12)
# Out:
#            주소명         위도          경도
# 0        화곡사거리  37.530607  126.847379
# 1      양동중학교입구  37.548092  126.869778
# 2    화곡터널남다교차로  37.527875  126.848838
# 3       마곡역교차로  37.559702  126.826872
# 4         신월초교  37.539666  126.839919
# 5     가양아파트교차로  37.563454  126.856676
# 6    강서그랜드아이파크  37.554851  126.851625
# 7       화곡본동시장  37.543634  126.843370
# 8   화곡부성약국앞사거리  37.531656  126.857933
# 9       KT강서지사  37.529242  126.848777
# 10  가양3-5단지교차로  37.562880  126.851697
# 11      개화역사거리  37.578325  126.800062

# %%
cctv_df = cctv_df[cctv_df['주소명'] != '개화역사거리']
cctv_df.head(12)
# Out:
#            주소명         위도          경도
# 0        화곡사거리  37.530607  126.847379
# 1      양동중학교입구  37.548092  126.869778
# 2    화곡터널남다교차로  37.527875  126.848838
# 3       마곡역교차로  37.559702  126.826872
# 4         신월초교  37.539666  126.839919
# 5     가양아파트교차로  37.563454  126.856676
# 6    강서그랜드아이파크  37.554851  126.851625
# 7       화곡본동시장  37.543634  126.843370
# 8   화곡부성약국앞사거리  37.531656  126.857933
# 9       KT강서지사  37.529242  126.848777
# 10  가양3-5단지교차로  37.562880  126.851697

# %%
import folium

cctv_df["위도"].mean()
cctv_df["경도"].mean()

map = folium.Map(location=[cctv_df["위도"].mean(),cctv_df["경도"].mean()], zoom_start=1)

for n in cctv_df.index:
    name = cctv_df.loc[n, "주소명"]
    popup = f"{name}-{address}"
    location = [cctv_df.loc[n, "위도"], cctv_df.loc[n, "경도"]]
    folium.Marker(
        location = location,
        popup = popup,
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58bec4ca6630d024b6b29f49a16a8aed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58bec4ca6630d024b6b29f49a16a8aed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58bec4ca6630d024b6b29f49a16a8aed = L.map(
#                 &quot;map_58bec4ca6630d024b6b29f49a16a8aed&quot;,
#                 {
#                     center: [37.54469627272727, 126.84935127272728],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29e75089b2a656a6a9ae23dc8822101a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_58bec4ca6630d024b6b29f49a16a8aed);
#
#
#             var marker_5f2a697bf1ec5df556dc85e2764e06aa = L.marker(
#                 [37.530607, 126.847379],
#                 {}
#             ).addTo(map_58bec4ca6630d024b6b29f49a16a8aed);
#
#
#         var popup_6ea93b3d705d31ec271fefa6b19696c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc89b30f83244d5915dbd3a014596902 = $(`&lt;div id=&quot;html_bc89b30f83244d5915dbd3a014596902&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;화곡사거리-서울특별시 강서구 염창동 102-1&lt;/div&gt;`)[0];
#                 popup_6ea93b3d705d31ec271fefa6b19696c4.setContent(html_bc89b30f83244d5915dbd3a014596902);
#
#
#
#         marker_5f2a697bf1ec5df556dc85e2764e06aa.bindPopup(popup_6ea93b3d705d31ec271fefa6b19696c4)
#         ;
#
#
#
#
#             var marker_99e4735b2764b984040ac84184760c28 = L.marker(
#                 [37.548092, 126.869778],
#                 {}
#             ).addTo(map_58bec4ca6630d024b6b29f49a16a8aed);
#
#
#         var popup_5f0c01f9ac70b3d76017492c3b9fef9b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5eb6c5f8b0c205633c4698680f625369 = $(`&lt;div id=&quot;html_5eb6c5f8b0c205633c4698680f625369&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;양동중학교입구-서울특별시 강서구 염창동 102-1&lt;/div&gt;`)[0];
#                 popup_5f0c01f9ac70b3d76017492c3b9fef9b.setContent(html_5eb6c5f8b0c205633c4698680f625369);
#
#
#
#         marker_99e4735b2764b984040ac84184760c28.bindPopup(popup_5f0c01f9ac70b3d76017492c3b9fef9b)
#         ;
#
#
#
#
#             var marker_3df0599ebadf9e71c1b2340e8387c275 = L.marker(
#                 [37.527875, 126.848838],
#                 {}
#             ).addTo(map_58bec4ca6630d024b6b29f49a16a8aed);
#
#
#         var popup_1577ba54cd5d54b53369fd6ab6465b9b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_195be2c3aca20ffb10816539a266051c = $(`&lt;div id=&quot;html_195be2c3aca20ffb10816539a266051c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;화곡터널남다교차로-서울특별시 강서구 염창동 102-1&lt;/div&gt;`)[0];
#                 popup_1577ba54cd5d54b53369fd6ab6465b9b.setContent(html_195be2c3aca20ffb10816539a266051c);
#
#
#
#         marker_3df0599ebadf9e71c1b2340e8387c275.bindPopup(popup_1577ba54cd5d54b53369fd6ab6465b9b)
#         ;
#
#
#
#
#             var marker_b0cdb314d0950beea0780e3056760254 = L.marker(
#                 [37.559702, 126.826872],
#                 {}
#             ).addTo(map_58bec4ca6630d024b6b29f49a16a8aed);
#
#
#         var popup_347f04a4d0cdab3282ac81ecabf1af51 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1422a9b9af42dc0dc0059a7e10b6e3c = $(`&lt;div id=&quot;html_f1422a9b9af42dc0dc0059a7e10b6e3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;마곡역교차로-서울특별시 강서구 염창동 102-1&lt;/div&gt;`)[0];
#                 popup_347f04a4d0cdab3282ac81ecabf1af51.setContent(html_f1422a9b9af42dc0dc0059a7e10b6e3c);
#
#
#
#         marker_b0cdb314d0950beea0780e3056760254.bindPopup(popup_347f04a4d0cdab3282ac81ecabf1af51)
#         ;
#
#
#
#
#             var marker_2629888a40cf5575ad1b03f83f1813ad = L.marker(
#                 [37.539666, 126.839919],
#                 {}
#             ).addTo(map_58bec4ca6630d024b6b29f49a16a8aed);
#
#
#         var popup_33ac5a1cfef931989fa66e6ff0879a9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d01ab058eebe864b3e1adb2f80f1a782 = $(`&lt;div id=&quot;html_d01ab058eebe864b3e1adb2f80f1a782&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신월초교-서울특별시 강서구 염창동 102-1&lt;/div&gt;`)[0];
#                 popup_33ac5a1cfef931989fa66e6ff0879a9f.setContent(html_d01ab058eebe864b3e1adb2f80f1a782);
#
#
#
#         marker_2629888a40cf5575ad1b03f83f1813ad.bindPopup(popup_33ac5a1cfef931989fa66e6ff0879a9f)
#         ;
#
#
#
#
#             var marker_546bc07eb29027

# %% [markdown]
# # 후보지와 cctv 위치 표시

# %%
import pandas as pd
import folium

# 후보지 데이터 로드
hu_df = pd.read_csv('/Users/raekkkky/Desktop/DNA/[24 1학기] 🏆승승장구/6주차/후보지 예시.csv', encoding='utf-8-sig')

# CCTV 데이터 로드
cctv_df = pd.read_csv('/Users/raekkkky/Desktop/DNA/[24 1학기] 🏆승승장구/5주차/최종 cctv 위경도.csv', encoding='utf-8-sig')

# 지도의 중심을 두 데이터셋의 위도와 경도 평균으로 설정
map_center = [
    (hu_df["위도"].mean() + cctv_df["위도"].mean()) / 2,
    (hu_df["경도"].mean() + cctv_df["경도"].mean()) / 2
]

map = folium.Map(location=map_center, zoom_start=10)

# 후보지에 파란색 마커 추가
for n in hu_df.index:
    name = hu_df.loc[n, "주소명"]
    popup = f"{name}"
    location = [hu_df.loc[n, "위도"], hu_df.loc[n, "경도"]]
    folium.Marker(
        location=location,
        popup=popup,
        icon=folium.Icon(color='blue')  # 파란색 마커로 설정
    ).add_to(map)

# CCTV 위치에 빨간색 마커 추가
for n in cctv_df.index:
    name = cctv_df.loc[n, "행정동"]
    address = cctv_df.loc[n, "주소"]
    popup = f"{name}-{address}"
    location = [cctv_df.loc[n, "위도"], cctv_df.loc[n, "경도"]]
    folium.Marker(
        location=location,
        popup=popup,
        icon=folium.Icon(color='red')  # 빨간색 마커로 설정
    ).add_to(map)

# 지도 표시
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_704023ae7f451afbb83367d5a9756d68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_704023ae7f451afbb83367d5a9756d68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_704023ae7f451afbb83367d5a9756d68 = L.map(
#                 &quot;map_704023ae7f451afbb83367d5a9756d68&quot;,
#                 {
#                     center: [37.55259658928571, 126.84079271428573],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb4d590431331c9d1aadf4a5793e7ede = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_704023ae7f451afbb83367d5a9756d68);
#
#
#             var marker_4af226e7727963b58d95748ebc90981e = L.marker(
#                 [37.530607, 126.847379],
#                 {}
#             ).addTo(map_704023ae7f451afbb83367d5a9756d68);
#
#
#             var icon_25ffc2c1c70816f7db7f4c5c9df319a8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4af226e7727963b58d95748ebc90981e.setIcon(icon_25ffc2c1c70816f7db7f4c5c9df319a8);
#
#
#         var popup_f8020e666fff838ded988d4a1bc8d97c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c820d4985e7afec3f425290100d11af = $(`&lt;div id=&quot;html_3c820d4985e7afec3f425290100d11af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;화곡사거리&lt;/div&gt;`)[0];
#                 popup_f8020e666fff838ded988d4a1bc8d97c.setContent(html_3c820d4985e7afec3f425290100d11af);
#
#
#
#         marker_4af226e7727963b58d95748ebc90981e.bindPopup(popup_f8020e666fff838ded988d4a1bc8d97c)
#         ;
#
#
#
#
#             var marker_96c509f8e42f2555e8744618a6d85da3 = L.marker(
#                 [37.548092, 126.869778],
#                 {}
#             ).addTo(map_704023ae7f451afbb83367d5a9756d68);
#
#
#             var icon_089c414f51384570693c4495e96d09df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_96c509f8e42f2555e8744618a6d85da3.setIcon(icon_089c414f51384570693c4495e96d09df);
#
#
#         var popup_b42b419b629d3860070060a99ef6922d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bf3acff6761fe48754e448e5db5f6d1 = $(`&lt;div id=&quot;html_6bf3acff6761fe48754e448e5db5f6d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;양동중학교입구&lt;/div&gt;`)[0];
#                 popup_b42b419b629d3860070060a99ef6922d.setContent(html_6bf3acff6761fe48754e448e5db5f6d1);
#
#
#
#         marker_96c509f8e42f2555e8744618a6d85da3.bindPopup(popup_b42b419b629d3860070060a99ef6922d)
#         ;
#
#
#
#
#             var marker_e09eb8b393896de6208660f48b44e14e = L.marker(
#                 [37.527875, 126.848838],
#                 {}
#             ).addTo(map_704023ae7f451afbb83367d5a9756d68);
#
#
#             var icon_4c448d7ec2996caa58d933b45a573a87 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e09eb8b393896de6208660f48b44e14e.setIcon(icon_4c448d7ec2996caa58d933b45a573a87);
#
#
#         var popup_78e383dbdf4ee0ade8d9a0d4da277318 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_28e865d2dc95c1b4aa0f1cfaeff93878 = $(`&lt;div id=&quot;html_28e865d2dc95c1b4aa0f1cfaeff93878&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;화곡터널남다교차로&lt;/div&gt;`)[0];
#                 popup_78e383dbdf4ee0ade8d9a0d4da277318.setContent(html_28e865d2dc95c1b4aa0f1cfaeff93878);
#
#
#
#         marker_e09eb8b393896de6208660f48b44e14e.bindPopup(popup_78e383dbdf4ee0ade8d9a0d4da277318)
#         ;
#
#
#
#
#             var marker_d65fbe2c503040f010c6947a2a17409a = L.marker(
#                 [37.559702, 126.826872],
#                 {}
#             ).addTo(map_704023ae7f451afbb83367d5a9756d68);
#
#
#             var icon_421fcbf5ea79561058a85de6050280c1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot

# %% [markdown]
# # 작업중
